# %%
import json
from sentence_transformers import SentenceTransformer, util
import pandas as pd
from glob import glob
from itertools import product
import re

# %%
with open("checkpoints/requirements_extraction/claude_reqs_list_v1_20250429_081756.md") as f:
    mdreqs = f.read()

# %%
all_reqs = []
sections = list(re.finditer("#+ REQ-[0-9]+", mdreqs))
md_splits = []
for i in range(len(sections)-1):

    md_splits.append(mdreqs[sections[i].span()[1]:sections[i+1].span()[0]])
md_splits.append(mdreqs[sections[-1].span()[1]:])

counter = 0
for split in md_splits:
    headings = list(re.finditer("\*\*\w+\*\*\:", split))
    for i in range(len(headings)-1):
        heading = headings[i]
        if split[heading.span()[0]:heading.span()[1]].lower() == "**description**:":
            req_text = split[heading.span()[1]:headings[i+1].span()[0]]
            all_reqs.append({"text": req_text, "raw": split, "id": f"md{counter}"})
            counter += 1
            break
    heading = headings[-1]
    if split[heading.span()[0]:heading.span()[1]].lower() == "**description**:":
        req_text = split[heading.span()[1]:]
        all_reqs.append({"text": req_text, "raw": split, "id": f"md{counter}"})
        counter += 1

# %%
ragreq_list = []
with open("checkpoints/requirements_extraction/RAG/plan_net_reqs.json") as f:
    ragreqs = json.load(f)
for ragreq in ragreqs['responses']['processed']:
    if ragreq['contains_requirement']:
        ragreq_list.extend([{'text': x['Requirement*'], 'raw': x} for x in ragreq['extracted_requirement']])
counter = 0
for rl in ragreq_list:
    rl['id'] = f"rag{counter}"
    counter += 1

# %%
from uuid import uuid4

# %%
str(uuid4())
# Out:
# '91364f64-be7e-4138-ab09-3b7de4434c4f'

# %%
all_reqs.extend(ragreq_list)

# %%
all_reqs
# Out:
# [{'text': ' "Access to the Plan-Net service should not require authentication, and the server should not maintain any records that could associate the consumer with the entities that were queried."\n',
#   'raw': '\n\n**Summary**: No authentication for directory access\n**Description**: "Access to the Plan-Net service should not require authentication, and the server should not maintain any records that could associate the consumer with the entities that were queried."\n**Verification**: Inspection\n**Notes**: Actor: Server, Conformance: SHOULD, Conditional: False\n**Source**: Privacy Considerations Section\n\n',
#   'id': 'md0'},
#  {'text': ' "A conformant Plan-Net service SHALL NOT require a directory mobile application to send consumer identifying information in order to query content."\n',
#   'raw': '\n\n**Summary**: No consumer identification required\n**Description**: "A conformant Plan-Net service SHALL NOT require a directory mobile application to send consumer identifying information in order to query content."\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL NOT, Conditional: False\n**Source**: Privacy Considerations Section\n\n',
#   'id': 'md1'},
#  {'text': ' "A directory mobile application SHALL NOT send consumer identifiable information when querying a Plan-Net service."\n',
#   'raw': '\n\n**Summary**: No consumer information sent in queries\n**Description**: "A directory mobile application SHALL NOT send consumer identifiable information when querying a Plan-Net service."\n**Verification**: Test\n**Notes**: Actor: Client Application, Conformance: SHALL NOT, Conditional: False\n**Source**: Privacy Considerations Section\n\n',
#   'id': 'md2',
#   'embedding': array([-7.70624960e-03,  1.31730735e-02, -2.93681547e-02, -1.37257343e-02,
#           1.34407636e-02, -9.22984257e-03,  9.07451957e-02, -3.99158821e-02,
#           5.51518239e-03, -7.39378901e-03,  2.33682292e-03, -8.79584067e-03,
#          -3.16483118e-02,  1.89996846e-02, -7.78078362e-02, -1.67132299e-02,
#           4.70407829e-02,  1.92315020e-02,  2.87412312e-02, -1.10830450e-02,
#           4.29854244e-02, -3.26900091e-03, -2.17042919e-02, -3.24912295e-02,
#           3.12328171e-02, -1.79857444e-02,  2.05777418e-02,  3.30609409e-03,
#          -2.47744061e-02,  4.23482619e-02, -3.40464748e-02,  5.98129667e-02,
#           3.78195830e-02,  2.79262289e-02, -1.31411497e-02, -1.57700963e-02,
#           5.49581908e-02, -3.53310406e-02,  9.98678152e-03,  1.94757022e-02,
#           1.74780765e-34, -1.57642849e-02, -1.07953418e-02,  8.52167793e-03,
#           1.09977564e-02, -5.69850095e-02, -1.43245431e-02,  1.11308008e-01,
#           2.15744171e-02, -7.77984923e-03, -2.30935849e-02,  1.08337752e-03],
#         dtype=float32)},
#  {'text': ' "Each profile in this guide requires that the lastUpdate timestamp be provided as part of the profile\'s data content."\n',
#   'raw': '\n\n**Summary**: LastUpdate timestamp inclusion\n**Description**: "Each profile in this guide requires that the lastUpdate timestamp be provided as part of the profile\'s data content."\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL (implied by "requires"), Conditional: False\n**Source**: Client Detection of Updates Directory Content Section',
#   'id': 'md3'},
#  {'text': ' "A server MAY support [Bulk Data IG] for the retrieval of directory data."\n',
#   'raw': '\n\n**Summary**: Optional Bulk Data Support\n**Description**: "A server MAY support [Bulk Data IG] for the retrieval of directory data."\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: MAY, Conditional: False\n**Source**: Bulk Data Section',
#   'id': 'md4'},
#  {'text': ' "The Plan-Net Server SHALL Support all profiles defined in this Implementation Guide."\n',
#   'raw': '\n\n**Summary**: Server Mandatory Profile Support\n**Description**: "The Plan-Net Server SHALL Support all profiles defined in this Implementation Guide."\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: FHIR RESTful Capabilities Section\n\n',
#   'id': 'md5'},
#  {'text': ' "The Plan-Net Server SHALL Implement the RESTful behavior according to the FHIR specification."\n',
#   'raw': '\n\n**Summary**: RESTful Behavior Implementation\n**Description**: "The Plan-Net Server SHALL Implement the RESTful behavior according to the FHIR specification."\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: FHIR RESTful Capabilities Section\n\n',
#   'id': 'md6'},
#  {'text': ' "The Plan-Net Server SHALL Return the following response classes: (Status 400): invalid parameter, (Status 401/4xx): unauthorized request, (Status 403): insufficient scope, (Status 404): unknown resource, (Status 410): deleted resource."\n',
#   'raw': '\n\n**Summary**: Response Class Support\n**Description**: "The Plan-Net Server SHALL Return the following response classes: (Status 400): invalid parameter, (Status 401/4xx): unauthorized request, (Status 403): insufficient scope, (Status 404): unknown resource, (Status 410): deleted resource."\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: FHIR RESTful Capabilities Section\n\n',
#   'id': 'md7'},
#  {'text': ' "The Plan-Net Server SHALL Support json source formats for all Plan-Net interactions."\n',
#   'raw': '\n\n**Summary**: JSON Format Support\n**Description**: "The Plan-Net Server SHALL Support json source formats for all Plan-Net interactions."\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: FHIR RESTful Capabilities Section\n\n',
#   'id': 'md8'},
#  {'text': ' "The Plan-Net Server SHALL Support the searchParameters on each profile individually and in combination."\n',
#   'raw': '\n\n**Summary**: Search Parameter Support\n**Description**: "The Plan-Net Server SHALL Support the searchParameters on each profile individually and in combination."\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: FHIR RESTful Capabilities Section\n\n',
#   'id': 'md9'},
#  {'text': ' "The Plan-Net Server SHOULD Support xml source formats for all Plan-Net interactions."\n',
#   'raw': '\n\n**Summary**: XML Format Support\n**Description**: "The Plan-Net Server SHOULD Support xml source formats for all Plan-Net interactions."\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHOULD, Conditional: False\n**Source**: FHIR RESTful Capabilities Section\n\n',
#   'id': 'md10'},
#  {'text': ' "A server SHALL reject any unauthorized requests by returning an HTTP 401 unauthorized response code."\n',
#   'raw': '\n\n**Summary**: Unauthorized Request Handling\n**Description**: "A server SHALL reject any unauthorized requests by returning an HTTP 401 unauthorized response code."\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: Security Section\n\n',
#   'id': 'md11'},
#  {'text': ' "A Server SHALL be capable of returning a Endpoint resource using: GET [base]/Endpoint/[id]"\n',
#   'raw': '\n\n**Summary**: Endpoint Resource Support\n**Description**: "A Server SHALL be capable of returning a Endpoint resource using: GET [base]/Endpoint/[id]"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: Endpoint Section\n\n',
#   'id': 'md12'},
#  {'text': ' "A Server SHALL be capable of supporting the following _includes: Endpoint:organization - GET [base]/Endpoint?[parameter=value]&_include=Endpoint:organization"\n',
#   'raw': '\n\n**Summary**: Endpoint Search Support\n**Description**: "A Server SHALL be capable of supporting the following _includes: Endpoint:organization - GET [base]/Endpoint?[parameter=value]&_include=Endpoint:organization"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: Endpoint Section',
#   'id': 'md13'},
#  {'text': ' "Server SHALL support search-type, read"\n',
#   'raw': '\n**Summary**: Support HealthcareService basic interactions\n**Description**: "Server SHALL support search-type, read"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL\n**Source**: HealthcareService Profile Interaction Summary\n\n',
#   'id': 'md14',
#   'embedding': array([ 2.95918025e-02, -3.07022296e-02,  3.30080688e-02,  1.70517266e-02,
#           3.85422930e-02,  4.82115615e-03, -1.73824597e-02,  5.95685616e-02,
#           4.78079207e-02, -4.69662733e-02, -2.71155145e-02, -2.48041730e-02,
#          -1.37547217e-02,  2.12754775e-02, -2.21561864e-02, -1.71882240e-03,
#           5.41921891e-02,  5.37262717e-03,  2.83853663e-03, -2.96730194e-02,
#          -1.78565513e-02,  2.53184251e-02, -8.21731705e-03,  6.41021598e-03,
#           7.70174637e-02, -2.74876412e-02,  1.26803126e-02, -2.21985346e-03,
#          -4.47072312e-02, -4.95549031e-02,  3.99727486e-02, -5.09730130e-02,
#           2.00137831e-02, -2.36364398e-02,  1.42702288e-06,  7.73858605e-03,
#          -1.51296156e-02,  3.30842379e-03, -3.84692661e-02,  3.10502592e-02,
#          -6.35085115e-03,  2.24458668e-02,  4.13281359e-02,  4.12612855e-02,
#          -2.84583331e-03, -2.92556509e-02, -3.89342904e-02,  1.26817543e-02,
#          -1.63403936e-02,  8.77898261e-02,  2.72334702e-02,  1.83982514e-02,
#           6.48670655e-04, -3.65939699e-02,  3.24892774e-02, -2.41417028e-02,
#          -1.36257550e-02, -8.63279626e-02,  5.18679395e-02,  1.14820801e-01,
#           1.01161953e-02,  4.91509773e-02, -3.37836593e-02,  5.82284108e-02,
#          -5.75019605e-02,  1.95512716e-02,  2.24648882e-02, -2.83359569e-02,
#           8.35999027e-02, -3.05818282e-02,  9.00370330e-02,  6.41952679e-02,
#          -2.21110554e-03, -1.17034363e-02, -4.35806699e-02,  6.67830259e-02,
#           5.83259203e-02, -2.17552446e-02, -2.23133042e-02, -2.22371216e-03,
#          -2.20952630e-02, -3.12194023e-02,  2.98988130e-02, -1.46279205e-02,
\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL\n**Source**: HealthcareService Fetch and Search Criteria\n\n',
#   'id': 'md16'},
#  {'text': ' "A Server SHALL be capable of supporting the following _revincludes: PractitionerRole:service, OrganizationAffiliation:service"\n',
#   'raw': '\n**Summary**: Support HealthcareService reverse includes\n**Description**: "A Server SHALL be capable of supporting the following _revincludes: PractitionerRole:service, OrganizationAffiliation:service"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL\n**Source**: HealthcareService Fetch and Search Criteria\n\n',
#   'id': 'md17'},
#  {'text': ' "Server SHALL support search-type, read"\n',
#   'raw': '\n**Summary**: Support InsurancePlan basic interactions\n**Description**: "Server SHALL support search-type, read"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL\n**Source**: InsurancePlan Profile Interaction Summary\n\n',
#   'id': 'md18'},
#  {'text': ' "A Server SHALL be capable of returning a InsurancePlan resource using: GET [base]/InsurancePlan/[id]"\n',
#   'raw': '\n**Summary**: Support InsurancePlan fetch by ID\n**Description**: "A Server SHALL be capable of returning a InsurancePlan resource using: GET [base]/InsurancePlan/[id]"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL\n**Source**: InsurancePlan Fetch and Search Criteria\n\n',
#   'id': 'md19'},
#  {'text': ' "A Server SHALL be capable of supporting the following _includes: InsurancePlan:administered-by, InsurancePlan:owned-by, InsurancePlan:coverage-area"\n',
#   'raw': '\n**Summary**: Support InsurancePlan includes\n**Description**: "A Server SHALL be capable of supporting the following _includes: InsurancePlan:administered-by, InsurancePlan:owned-by, InsurancePlan:coverage-area"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL\n**Source**: InsurancePlan Fetch and Search Criteria\n\n',
#   'id': 'md20'},
#  {'text': ' "Server SHALL support search-type, read"\n',
#   'raw': '\n**Summary**: Support Location basic interactions\n**Description**: "Server SHALL support search-type, read"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL\n**Source**: Location Profile Interaction Summary\n\n',
#   'id': 'md21',
#   'embedding': array([ 2.95918025e-02, -3.07022296e-02,  3.30080688e-02,  1.70517266e-02,
#           3.85422930e-02,  4.82115615e-03, -1.73824597e-02,  5.95685616e-02,
#           4.78079207e-02, -4.69662733e-02, -2.71155145e-02, -2.48041730e-02,
#          -1.37547217e-02,  2.12754775e-02, -2.21561864e-02, -1.71882240e-03,
#           5.41921891e-02,  5.37262717e-03,  2.83853663e-03, -2.96730194e-02,
#          -1.78565513e-02,  2.53184251e-02, -8.21731705e-03,  6.41021598e-03,
#           7.70174637e-02, -2.74876412e-02,  1.26803126e-02, -2.21985346e-03,
#          -4.47072312e-02, -4.95549031e-02,  3.99727486e-02, -5.09730130e-02,
#           2.00137831e-02, -2.36364398e-02,  1.42702288e-06,  7.73858605e-03,
#          -1.51296156e-02,  3.30842379e-03, -3.84692661e-02,  3.10502592e-02,
#          -6.35085115e-03,  2.24458668e-02,  4.13281359e-02,  4.12612855e-02,
#          -2.84583331e-03, -2.92556509e-02, -3.89342904e-02,  1.26817543e-02,
#          -1.63403936e-02,  8.77898261e-02,  2.72334702e-02,  1.83982514e-02,
#           6.48670655e-04, -3.65939699e-02,  3.24892774e-02, -2.41417028e-02,
#          -1.36257550e-02, -8.63279626e-02,  5.18679395e-02,  1.14820801e-01,
#           1.01161953e-02,  4.91509773e-02, -3.37836593e-02,  5.82284108e-02,
#          -5.75019605e-02,  1.95512716e-02,  2.24648882e-02, -2.83359569e-02,
#           8.35999027e-02, -3.05818282e-02,  9.00370330e-02,  6.41952679e-02,
#          -2.21110554e-03, -1.17034363e-02, -4.35806699e-02,  6.67830259e-02,
#           5.83259203e-02, -2.17552446e-02, -2.23133042e-02, -2.22371216e-03,
#          -4.11207825e-02, -2.99043134e-02, -3.38886939e-02, -6.77611902e-02,
#          -9.35711898e-03,  1.44709861e-02,  5.28562292e-02, -4.48417775e-02,
#          -3.98128666e-02, -1.37453293e-02,  1.67137198e-02,  2.27593798e-02,
#           3.11086178e-02,  9.20775533e-03,  3.35022807e-02, -7.57036498e-04,
#           5.14210463e-02, -1.91732049e-02,  2.14715190e-02, -2.54846434e-03,
#           5.43745346e-02, -5.16952723e-02, -2.03146599e-03,  1.95292034e-03,
#           1.92842893e-02, -1.41180614e-02,  3.24183106e-02, -2.42683291e-02,
#           1.12039642e-02, -2.56934855e-03,  3.42054549e-03,  2.83729583e-02,
#           5.95810525e-02,  4.62733731e-02, -3.11571155e-02,  3.31937037e-02,
#          -2.48296987e-02,  2.68492494e-02,  7.87160471e-02, -2.87573319e-03,
# ...
#  {'text': 'Server SHALL support returning an OrganizationAffiliation resource using GET [base]/OrganizationAffiliation/[id]',
#   'raw': {'Requirement*': 'Server SHALL support returning an OrganizationAffiliation resource using GET [base]/OrganizationAffiliation/[id]',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Read'},
#   'id': 'rag99'},
#  {'text': 'Server SHALL support _include parameter for OrganizationAffiliation:primary-organization',
#   'raw': {'Requirement*': 'Server SHALL support _include parameter for OrganizationAffiliation:primary-organization',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag100'},
#  {'text': 'Server SHALL support _include parameter for OrganizationAffiliation:participating-organization',
#   'raw': {'Requirement*': 'Server SHALL support _include parameter for OrganizationAffiliation:participating-organization',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag101'},
#  {'text': 'Server SHALL support _include parameter for OrganizationAffiliation:location',
#   'raw': {'Requirement*': 'Server SHALL support _include parameter for OrganizationAffiliation:location',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag102'},
#  {'text': 'Server SHALL support _include parameter for OrganizationAffiliation:service',
#   'raw': {'Requirement*': 'Server SHALL support _include parameter for OrganizationAffiliation:service',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag103'},
#  {'text': 'Server SHALL support _include parameter for OrganizationAffiliation:endpoint',
#   'raw': {'Requirement*': 'Server SHALL support _include parameter for OrganizationAffiliation:endpoint',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag104'},
#  {'text': 'Server SHALL support _include parameter for OrganizationAffiliation:network',
#   'raw': {'Requirement*': 'Server SHALL support _include parameter for OrganizationAffiliation:network',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag105'},
#  {'text': 'Server SHALL support primary-organization search parameter for OrganizationAffiliation',
#   'raw': {'Requirement*': 'Server SHALL support primary-organization search parameter for OrganizationAffiliation',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Search'},
#   'id': 'rag106'},
#  {'text': 'Server SHALL support participating-organization search parameter for OrganizationAffiliation',
#   'raw': {'Requirement*': 'Server SHALL support participating-organization search parameter for OrganizationAffiliation',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Search'},
#   'id': 'rag107'},
#  {'text': 'Server SHALL support location search parameter for OrganizationAffiliation',
#   'raw': {'Requirement*': 'Server SHALL support location search parameter for OrganizationAffiliation',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Search'},
#   'id': 'rag108'},
#  {'text': 'Server SHALL support service search parameter for OrganizationAffiliation',
#   'raw': {'Requirement*': 'Server SHALL support service search parameter for OrganizationAffiliation',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Search'},
#   'id': 'rag109'},
#  {'text': 'Server SHALL support network search parameter for OrganizationAffiliation',
#   'raw': {'Requirement*': 'Server SHALL support network search parameter for OrganizationAffiliation',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Search'},
#   'id': 'rag110'},
#  {'text': 'Server SHALL support endpoint search parameter for OrganizationAffiliation',
#   'raw': {'Requirement*': 'Server SHALL support endpoint search parameter for OrganizationAffiliation',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Search'},
#   'id': 'rag111'},
#  {'text': 'Server SHALL support role search parameter for OrganizationAffiliation',
#   'raw': {'Requirement*': 'Server SHALL support role search parameter for OrganizationAffiliation',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Search'},
#   'id': 'rag112'},
#  {'text': 'Server SHALL support specialty search parameter for OrganizationAffiliation',
#   'raw': {'Requirement*': 'Server SHALL support specialty search parameter for OrganizationAffiliation',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Search'},
#   'id': 'rag113'},
#  {'text': 'Server SHALL support _id search parameter for OrganizationAffiliation',
#   'raw': {'Requirement*': 'Server SHALL support _id search parameter for OrganizationAffiliation',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Search'},
#   'id': 'rag114'},
#  {'text': 'Server SHALL support _lastUpdated search parameter for OrganizationAffiliation',
#   'raw': {'Requirement*': 'Server SHALL support _lastUpdated search parameter for OrganizationAffiliation',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Search'},
#   'id': 'rag115'},
#  {'text': 'Profile Support: SHALL support Plan-Net Practitioner profile',
#   'raw': {'Requirement*': 'Profile Support: SHALL support Plan-Net Practitioner profile',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Profile Support',
#    'Test Plan': 'Verify profile is listed in CapabilityStatement',
#    'Simulation Approach': 'SIMULATED: Profile will be listed in CapabilityStatement'},
#   'id': 'rag116'},
#  {'text': 'SHALL support search-type interaction',
#   'raw': {'Requirement*': 'SHALL support search-type interaction',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Interactions',
#    'Test Plan': 'Verify search interaction is listed in CapabilityStatement and test search functionality',
#    'Simulation Approach': 'SIMULATED: Search interaction will be supported'},
#   'id': 'rag117'},
#  {'text': 'SHALL support read interaction',
#   'raw': {'Requirement*': 'SHALL support read interaction',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Interactions',
#    'Test Plan': 'Verify read interaction is listed in CapabilityStatement and test read functionality',
#    'Simulation Approach': 'SIMULATED: Read interaction will be supported'},
#   'id': 'rag118'},
#  {'text': 'SHOULD support vread interaction',
#   'raw': {'Requirement*': 'SHOULD support vread interaction',
#    'Conformance*': 'SHOULD',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Interactions',
#    'Test Plan': 'Verify vread interaction is listed in CapabilityStatement if supported',
#    'Simulation Approach': 'SIMULATED: VRead interaction will be supported'},
#   'id': 'rag119'},
#  {'text': 'SHALL support _revinclude of PractitionerRole:practitioner',
#   'raw': {'Requirement*': 'SHALL support _revinclude of PractitionerRole:practitioner',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameters',
#    'Test Plan': 'Test search with _revinclude parameter',
#    'Simulation Approach': 'SIMULATED: _revinclude parameter will be supported'},
#   'id': 'rag120'},
#  {'text': 'SHALL support name search parameter',
#   'raw': {'Requirement*': 'SHALL support name search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameters',
#    'Test Plan': 'Test search using name parameter',
#    'Simulation Approach': 'SIMULATED: Name search parameter will be supported'},
#   'id': 'rag121'},
#  {'text': 'SHALL support _id search parameter',
#   'raw': {'Requirement*': 'SHALL support _id search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameters',
#    'Test Plan': 'Test search using _id parameter',
#    'Simulation Approach': 'SIMULATED: _id search parameter will be supported'},
#   'id': 'rag122'},
#  {'text': 'SHALL support _lastUpdated search parameter',
#   'raw': {'Requirement*': 'SHALL support _lastUpdated search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameters',
#    'Test Plan': 'Test search using _lastUpdated parameter',
#    'Simulation Approach': 'SIMULATED: _lastUpdated search parameter will be supported'},
#   'id': 'rag123'},
#  {'text': 'SHALL support family search parameter',
#   'raw': {'Requirement*': 'SHALL support family search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameters',
#    'Test Plan': 'Test search using family parameter',
#    'Simulation Approach': 'SIMULATED: Family search parameter will be supported'},
#   'id': 'rag124'},
#  {'text': 'SHALL support given search parameter',
#   'raw': {'Requirement*': 'SHALL support given search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameters',
#    'Test Plan': 'Test search using given parameter',
#    'Simulation Approach': 'SIMULATED: Given search parameter will be supported'},
#   'id': 'rag125'},
#  {'text': 'PractitionerRole Conformance Expectation: SHALL',
#   'raw': {'Requirement*': 'PractitionerRole Conformance Expectation: SHALL',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'CapabilityStatement'},
#   'id': 'rag126'},
#  {'text': 'Server SHALL support search-type interaction for PractitionerRole',
#   'raw': {'Requirement*': 'Server SHALL support search-type interaction for PractitionerRole',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search'},
#   'id': 'rag127'},
#  {'text': 'Server SHALL support read interaction for PractitionerRole',
#   'raw': {'Requirement*': 'Server SHALL support read interaction for PractitionerRole',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Read'},
#   'id': 'rag128'},
#  {'text': 'Server SHOULD support vread interaction for PractitionerRole',
#   'raw': {'Requirement*': 'Server SHOULD support vread interaction for PractitionerRole',
#    'Conformance*': 'SHOULD',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Version Read'},
#   'id': 'rag129'},
#  {'text': 'Server SHALL support _include=PractitionerRole:practitioner',
#   'raw': {'Requirement*': 'Server SHALL support _include=PractitionerRole:practitioner',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag130'},
#  {'text': 'Server SHALL support _include=PractitionerRole:organization',
#   'raw': {'Requirement*': 'Server SHALL support _include=PractitionerRole:organization',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag131'},
#  {'text': 'Server SHALL support _include=PractitionerRole:location',
#   'raw': {'Requirement*': 'Server SHALL support _include=PractitionerRole:location',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag132'},
#  {'text': 'Server SHALL support _include=PractitionerRole:service',
#   'raw': {'Requirement*': 'Server SHALL support _include=PractitionerRole:service',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag133'},
#  {'text': 'Server SHALL support _include=PractitionerRole:network',
#   'raw': {'Requirement*': 'Server SHALL support _include=PractitionerRole:network',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag134'},
#  {'text': 'Server SHALL support _include=PractitionerRole:endpoint',
#   'raw': {'Requirement*': 'Server SHALL support _include=PractitionerRole:endpoint',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag135'},
#  {'text': 'Server SHALL support practitioner search parameter',
#   'raw': {'Requirement*': 'Server SHALL support practitioner search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameter'},
#   'id': 'rag136'},
#  {'text': 'Server SHALL support organization search parameter',
#   'raw': {'Requirement*': 'Server SHALL support organization search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameter'},
#   'id': 'rag137'},
#  {'text': 'Server SHALL support location search parameter',
#   'raw': {'Requirement*': 'Server SHALL support location search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameter'},
#   'id': 'rag138'},
#  {'text': 'Server SHALL support service search parameter',
#   'raw': {'Requirement*': 'Server SHALL support service search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameter'},
#   'id': 'rag139'},
#  {'text': 'Server SHALL support network search parameter',
#   'raw': {'Requirement*': 'Server SHALL support network search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameter'},
#   'id': 'rag140'},
#  {'text': 'Server SHALL support endpoint search parameter',
#   'raw': {'Requirement*': 'Server SHALL support endpoint search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameter'},
#   'id': 'rag141'},
#  {'text': 'Server SHALL support role search parameter',
#   'raw': {'Requirement*': 'Server SHALL support role search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameter'},
#   'id': 'rag142'},
#  {'text': 'Server SHALL support specialty search parameter',
#   'raw': {'Requirement*': 'Server SHALL support specialty search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameter'},
#   'id': 'rag143'},
#  {'text': 'Server SHALL support _id search parameter',
#   'raw': {'Requirement*': 'Server SHALL support _id search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameter'},
#   'id': 'rag144'},
#  {'text': 'Server SHALL support _lastUpdated search parameter',
#   'raw': {'Requirement*': 'Server SHALL support _lastUpdated search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameter'},
#   'id': 'rag145'}]

# %%
model = SentenceTransformer("all-mpnet-base-v2")

for i, areq in enumerate(all_reqs):
    if (i+1) % 50 == 0:
        print(f"{i+1} of {len(all_reqs)}", end='\r')
    areq['embedding'] = model.encode(areq['text'])
# Out:
# 200 of 232

# %%
scored_prod_list = [['Requirement1', "Requirement2", "Similarity Score"]]
prod_list = list(product(all_reqs, all_reqs))
for i, prod in enumerate(prod_list):
    counter = i+1
    if counter % 1000 == 0:
        print(f"Pair {counter} of {len(prod_list)}", end='\r')
    if prod[0]['id'] != prod[1]['id']:
        emb0 = prod[0]['embedding']
        emb1 = prod[1]['embedding']
        score = float(util.pytorch_cos_sim(emb0, emb1)[0][0])
        scored_prod_list.append([prod[0]['id'], prod[1]['id'], score])
print(f"Pair {counter} of {len(prod_list)}", end='\r')
# Out:
# Pair 53824 of 53824

# %%
df = pd.DataFrame(scored_prod_list[1:], columns=scored_prod_list[0])
df.head()
# Out:
#   Requirement1 Requirement2  Similarity Score
# 0          md0          md1          0.690880
# 1          md0          md2          0.724847
# 2          md0          md3          0.180561
# 3          md0          md4          0.228241
# 4          md0          md5          0.578607

# %%
dupdf = df[df['Similarity Score'] >= 0.98]
groups = {}
for r1 in set(list(dupdf['Requirement1'].unique()) + list(dupdf['Requirement2'].unique())):
    subdf = dupdf[(dupdf['Requirement1'] == r1)|(dupdf['Requirement2'] == r1)]
    grouped_ids = set(subdf['Requirement1'].to_list() + subdf['Requirement2'].to_list())
    for gid in grouped_ids:
        if gid not in groups:
            groups[gid] = grouped_ids
        else:
            new_group = groups[gid].union(grouped_ids)
            groups[gid] = new_group 

unique_groups = set()
for val in groups.values():
    unique_groups.add(frozenset(val))

to_keep = []
dup_ids = []
for ugroup in unique_groups:
    glist = list(ugroup)
    to_keep.append(glist[0])
    dup_ids.extend(glist[1:])
    
filtered_allreqs = list(filter(lambda x: x['id'] not in dup_ids, all_reqs))

# %%
embeds_only = {}
for areq in filtered_allreqs:
    embeds_only[areq['id']] = [float(x) for x in areq.pop('embedding')]

# %%
filtered_allreqs
# Out:
# [{'text': ' "Access to the Plan-Net service should not require authentication, and the server should not maintain any records that could associate the consumer with the entities that were queried."\n',
#   'raw': '\n\n**Summary**: No authentication for directory access\n**Description**: "Access to the Plan-Net service should not require authentication, and the server should not maintain any records that could associate the consumer with the entities that were queried."\n**Verification**: Inspection\n**Notes**: Actor: Server, Conformance: SHOULD, Conditional: False\n**Source**: Privacy Considerations Section\n\n',
#   'id': 'md0'},
#  {'text': ' "A conformant Plan-Net service SHALL NOT require a directory mobile application to send consumer identifying information in order to query content."\n',
#   'raw': '\n\n**Summary**: No consumer identification required\n**Description**: "A conformant Plan-Net service SHALL NOT require a directory mobile application to send consumer identifying information in order to query content."\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL NOT, Conditional: False\n**Source**: Privacy Considerations Section\n\n',
#   'id': 'md1'},
#  {'text': ' "Each profile in this guide requires that the lastUpdate timestamp be provided as part of the profile\'s data content."\n',
#   'raw': '\n\n**Summary**: LastUpdate timestamp inclusion\n**Description**: "Each profile in this guide requires that the lastUpdate timestamp be provided as part of the profile\'s data content."\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL (implied by "requires"), Conditional: False\n**Source**: Client Detection of Updates Directory Content Section',
#   'id': 'md3'},
#  {'text': ' "A server MAY support [Bulk Data IG] for the retrieval of directory data."\n',
#   'raw': '\n\n**Summary**: Optional Bulk Data Support\n**Description**: "A server MAY support [Bulk Data IG] for the retrieval of directory data."\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: MAY, Conditional: False\n**Source**: Bulk Data Section',
#   'id': 'md4'},
#  {'text': ' "The Plan-Net Server SHALL Support all profiles defined in this Implementation Guide."\n',
#   'raw': '\n\n**Summary**: Server Mandatory Profile Support\n**Description**: "The Plan-Net Server SHALL Support all profiles defined in this Implementation Guide."\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: FHIR RESTful Capabilities Section\n\n',
#   'id': 'md5'},
#  {'text': ' "The Plan-Net Server SHALL Implement the RESTful behavior according to the FHIR specification."\n',
#   'raw': '\n\n**Summary**: RESTful Behavior Implementation\n**Description**: "The Plan-Net Server SHALL Implement the RESTful behavior according to the FHIR specification."\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: FHIR RESTful Capabilities Section\n\n',
#   'id': 'md6'},
#  {'text': ' "The Plan-Net Server SHALL Return the following response classes: (Status 400): invalid parameter, (Status 401/4xx): unauthorized request, (Status 403): insufficient scope, (Status 404): unknown resource, (Status 410): deleted resource."\n',
#   'raw': '\n\n**Summary**: Response Class Support\n**Description**: "The Plan-Net Server SHALL Return the following response classes: (Status 400): invalid parameter, (Status 401/4xx): unauthorized request, (Status 403): insufficient scope, (Status 404): unknown resource, (Status 410): deleted resource."\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: FHIR RESTful Capabilities Section\n\n',
#   'id': 'md7'},
#  {'text': ' "The Plan-Net Server SHALL Support json source formats for all Plan-Net interactions."\n',
#   'raw': '\n\n**Summary**: JSON Format Support\n**Description**: "The Plan-Net Server SHALL Support json source formats for all Plan-Net interactions."\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: FHIR RESTful Capabilities Section\n\n',
#   'id': 'md8'},
#  {'text': ' "The Plan-Net Server SHALL Support the searchParameters on each profile individually and in combination."\n',
#   'raw': '\n\n**Summary**: Search Parameter Support\n**Description**: "The Plan-Net Server SHALL Support the searchParameters on each profile individually and in combination."\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: FHIR RESTful Capabilities Section\n\n',
#   'id': 'md9'},
#  {'text': ' "The Plan-Net Server SHOULD Support xml source formats for all Plan-Net interactions."\n',
#   'raw': '\n\n**Summary**: XML Format Support\n**Description**: "The Plan-Net Server SHOULD Support xml source formats for all Plan-Net interactions."\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHOULD, Conditional: False\n**Source**: FHIR RESTful Capabilities Section\n\n',
#   'id': 'md10'},
#  {'text': ' "A server SHALL reject any unauthorized requests by returning an HTTP 401 unauthorized response code."\n',
#   'raw': '\n\n**Summary**: Unauthorized Request Handling\n**Description**: "A server SHALL reject any unauthorized requests by returning an HTTP 401 unauthorized response code."\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: Security Section\n\n',
#   'id': 'md11'},
#  {'text': ' "A Server SHALL be capable of returning a Endpoint resource using: GET [base]/Endpoint/[id]"\n',
#   'raw': '\n\n**Summary**: Endpoint Resource Support\n**Description**: "A Server SHALL be capable of returning a Endpoint resource using: GET [base]/Endpoint/[id]"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: Endpoint Section\n\n',
#   'id': 'md12'},
#  {'text': ' "A Server SHALL be capable of supporting the following _includes: Endpoint:organization - GET [base]/Endpoint?[parameter=value]&_include=Endpoint:organization"\n',
#   'raw': '\n\n**Summary**: Endpoint Search Support\n**Description**: "A Server SHALL be capable of supporting the following _includes: Endpoint:organization - GET [base]/Endpoint?[parameter=value]&_include=Endpoint:organization"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: Endpoint Section',
#   'id': 'md13'},
#  {'text': ' "A Server SHALL be capable of returning a HealthcareService resource using: GET [base]/HealthcareService/[id]"\n',
#   'raw': '\n**Summary**: Support HealthcareService fetch by ID\n**Description**: "A Server SHALL be capable of returning a HealthcareService resource using: GET [base]/HealthcareService/[id]"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL\n**Source**: HealthcareService Fetch and Search Criteria\n\n',
#   'id': 'md15'},
#  {'text': ' "A Server SHALL be capable of supporting the following _includes: HealthcareService:location, HealthcareService:coverage-area, HealthcareService:organization, HealthcareService:endpoint"\n',
#   'raw': '\n**Summary**: Support HealthcareService includes\n**Description**: "A Server SHALL be capable of supporting the following _includes: HealthcareService:location, HealthcareService:coverage-area, HealthcareService:organization, HealthcareService:endpoint"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL\n**Source**: HealthcareService Fetch and Search Criteria\n\n',
#   'id': 'md16'},
#  {'text': ' "A Server SHALL be capable of supporting the following _revincludes: PractitionerRole:service, OrganizationAffiliation:service"\n',
#   'raw': '\n**Summary**: Support HealthcareService reverse includes\n**Description**: "A Server SHALL be capable of supporting the following _revincludes: PractitionerRole:service, OrganizationAffiliation:service"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL\n**Source**: HealthcareService Fetch and Search Criteria\n\n',
#   'id': 'md17'},
#  {'text': ' "Server SHALL support search-type, read"\n',
#   'raw': '\n**Summary**: Support InsurancePlan basic interactions\n**Description**: "Server SHALL support search-type, read"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL\n**Source**: InsurancePlan Profile Interaction Summary\n\n',
#   'id': 'md18'},
#  {'text': ' "A Server SHALL be capable of returning a InsurancePlan resource using: GET [base]/InsurancePlan/[id]"\n',
#   'raw': '\n**Summary**: Support InsurancePlan fetch by ID\n**Description**: "A Server SHALL be capable of returning a InsurancePlan resource using: GET [base]/InsurancePlan/[id]"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL\n**Source**: InsurancePlan Fetch and Search Criteria\n\n',
#   'id': 'md19'},
#  {'text': ' "A Server SHALL be capable of supporting the following _includes: InsurancePlan:administered-by, InsurancePlan:owned-by, InsurancePlan:coverage-area"\n',
#   'raw': '\n**Summary**: Support InsurancePlan includes\n**Description**: "A Server SHALL be capable of supporting the following _includes: InsurancePlan:administered-by, InsurancePlan:owned-by, InsurancePlan:coverage-area"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL\n**Source**: InsurancePlan Fetch and Search Criteria\n\n',
#   'id': 'md20'},
#  {'text': ' "A Server SHALL be capable of returning a Location resource using: GET [base]/Location/[id]"\n',
#   'raw': '\n**Summary**: Support Location fetch by ID\n**Description**: "A Server SHALL be capable of returning a Location resource using: GET [base]/Location/[id]"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL\n**Source**: Location Fetch and Search Criteria\n\n',
#   'id': 'md22'},
#  {'text': ' "A Server SHALL be capable of supporting the following _includes: Location:endpoint, Location:organization, Location:partof"\n',
#   'raw': '\n**Summary**: Support Location includes\n**Description**: "A Server SHALL be capable of supporting the following _includes: Location:endpoint, Location:organization, Location:partof"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL\n**Source**: Location Fetch and Search Criteria\n\n',
#   'id': 'md23'},
#  {'text': ' "A Server SHALL be capable of supporting the following _revincludes: HealthcareService:location, InsurancePlan:coverage-area, OrganizationAffiliation:location, PractitionerRole:location"\n',
#   'raw': '\n**Summary**: Support Location reverse includes\n**Description**: "A Server SHALL be capable of supporting the following _revincludes: HealthcareService:location, InsurancePlan:coverage-area, OrganizationAffiliation:location, PractitionerRole:location"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL\n**Source**: Location Fetch and Search Criteria',
#   'id': 'md24'},
#  {'text': ' "A Server SHALL be capable of returning a Organization resource using: GET [base]/Organization/[id]"\n',
#   'raw': '\n\n**Summary**: Support Organization Resource Read Operation\n**Description**: "A Server SHALL be capable of returning a Organization resource using: GET [base]/Organization/[id]"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: Organization Section, Fetch and Search Criteria\n\n',
#   'id': 'md25'},
#  {'text': ' "Server SHALL support the following search parameters: partof, endpoint, address, name, _id, _lastUpdated, type, coverage-area"\n',
#   'raw': '\n\n**Summary**: Support Organization Search Parameters\n**Description**: "Server SHALL support the following search parameters: partof, endpoint, address, name, _id, _lastUpdated, type, coverage-area"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: Organization Section, Search Parameter Summary\n\n',
#   'id': 'md27'},
#  {'text': ' "A Server SHALL be capable of supporting the following _includes: Organization:partof, Organization:endpoint, Organization:coverage-area"\n',
#   'raw': '\n\n**Summary**: Support Organization Resource Includes\n**Description**: "A Server SHALL be capable of supporting the following _includes: Organization:partof, Organization:endpoint, Organization:coverage-area"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: Organization Section, Fetch and Search Criteria\n\n',
#   'id': 'md28'},
#  {'text': ' "A Server SHALL be capable of supporting the following _revincludes: Endpoint:organization, HealthcareService:organization, InsurancePlan:administered-by, InsurancePlan:owned-by, OrganizationAffiliation:primary-organization, PractitionerRole:organization, PractitionerRole:network, OrganizationAffiliation:participating-organization"\n',
#   'raw': '\n\n**Summary**: Support Organization Resource Reverse Includes\n**Description**: "A Server SHALL be capable of supporting the following _revincludes: Endpoint:organization, HealthcareService:organization, InsurancePlan:administered-by, InsurancePlan:owned-by, OrganizationAffiliation:primary-organization, PractitionerRole:organization, PractitionerRole:network, OrganizationAffiliation:participating-organization"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: Organization Section, Fetch and Search Criteria\n\n',
#   'id': 'md29'},
#  {'text': ' "A Server SHALL be capable of returning a OrganizationAffiliation resource using: GET [base]/OrganizationAffiliation/[id]"\n',
#   'raw': '\n\n**Summary**: Support OrganizationAffiliation Resource Read\n**Description**: "A Server SHALL be capable of returning a OrganizationAffiliation resource using: GET [base]/OrganizationAffiliation/[id]"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: OrganizationAffiliation Section, Fetch and Search Criteria\n\n',
#   'id': 'md31'},
#  {'text': ' "Server SHALL support the following search parameters: primary-organization, participating-organization, location, service, network, endpoint, role, specialty, _id, _lastUpdated"\n',
#   'raw': '\n\n**Summary**: Support OrganizationAffiliation Search Parameters\n**Description**: "Server SHALL support the following search parameters: primary-organization, participating-organization, location, service, network, endpoint, role, specialty, _id, _lastUpdated"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: OrganizationAffiliation Section, Search Parameter Summary\n\n',
#   'id': 'md32'},
#  {'text': ' "A Server SHALL be capable of supporting the following _includes: OrganizationAffiliation:primary-organization, OrganizationAffiliation:participating-organization, OrganizationAffiliation:location, OrganizationAffiliation:service, OrganizationAffiliation:endpoint, OrganizationAffiliation:network"\n',
#   'raw': '\n\n**Summary**: Support OrganizationAffiliation Resource Includes\n**Description**: "A Server SHALL be capable of supporting the following _includes: OrganizationAffiliation:primary-organization, OrganizationAffiliation:participating-organization, OrganizationAffiliation:location, OrganizationAffiliation:service, OrganizationAffiliation:endpoint, OrganizationAffiliation:network"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: OrganizationAffiliation Section, Fetch and Search Criteria\n\n',
#   'id': 'md33'},
#  {'text': ' "A Server SHALL be capable of returning a Practitioner resource using: GET [base]/Practitioner/[id]"\n',
#   'raw': '\n\n**Summary**: Support Practitioner Resource Read\n**Description**: "A Server SHALL be capable of returning a Practitioner resource using: GET [base]/Practitioner/[id]"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: Practitioner Section, Fetch and Search Criteria\n\n',
#   'id': 'md35'},
#  {'text': ' "Server SHALL support the following search parameters: name, _id, _lastUpdated, family, given"\n',
#   'raw': '\n\n**Summary**: Support Practitioner Search Parameters\n**Description**: "Server SHALL support the following search parameters: name, _id, _lastUpdated, family, given"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: Practitioner Section, Search Parameter Summary\n\n',
#   'id': 'md36'},
#  {'text': ' "A Server SHALL be capable of supporting the following _revincludes: PractitionerRole:practitioner"\n',
#   'raw': '\n\n**Summary**: Support Practitioner Resource Reverse Includes\n**Description**: "A Server SHALL be capable of supporting the following _revincludes: PractitionerRole:practitioner"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL, Conditional: False\n**Source**: Practitioner Section, Fetch and Search Criteria',
#   'id': 'md37'},
#  {'text': ' "A Server SHALL be capable of returning a PractitionerRole resource using: GET [base]/PractitionerRole/[id]"\n',
#   'raw': '\n\n**Summary**: Return PractitionerRole by ID\n**Description**: "A Server SHALL be capable of returning a PractitionerRole resource using: GET [base]/PractitionerRole/[id]"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL\n**Source**: PractitionerRole Fetch and Search Criteria\n\n',
#   'id': 'md39'},
#  {'text': ' "A Server SHALL be capable of supporting the following _includes:\nPractitionerRole:practitioner\nPractitionerRole:organization\nPractitionerRole:location\nPractitionerRole:service\nPractitionerRole:network\nPractitionerRole:endpoint"\n',
#   'raw': '\n\n**Summary**: Support PractitionerRole includes\n**Description**: "A Server SHALL be capable of supporting the following _includes:\nPractitionerRole:practitioner\nPractitionerRole:organization\nPractitionerRole:location\nPractitionerRole:service\nPractitionerRole:network\nPractitionerRole:endpoint"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL\n**Source**: PractitionerRole Fetch and Search Criteria\n\n',
#   'id': 'md40'},
#  {'text': ' "Server SHALL support the following search parameters: practitioner, organization, location, service, network, endpoint, role, specialty, _id, _lastUpdated"\n',
#   'raw': '\n\n**Summary**: Support mandatory search parameters\n**Description**: "Server SHALL support the following search parameters: practitioner, organization, location, service, network, endpoint, role, specialty, _id, _lastUpdated"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL\n**Source**: PractitionerRole Search Parameter Summary\n\n',
#   'id': 'md41'},
#  {'text': ' "A Server SHOULD be capable of returning a PractitionerRole resource using: GET [base]/PractitionerRole/[id]/_history/vid"\n',
#   'raw': '\n\n**Summary**: Support version read\n**Description**: "A Server SHOULD be capable of returning a PractitionerRole resource using: GET [base]/PractitionerRole/[id]/_history/vid"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHOULD\n**Source**: PractitionerRole Fetch and Search Criteria\n\n',
#   'id': 'md42'},
#  {'text': ' "Server SHOULD support vread"\n',
#   'raw': '\n\n**Summary**: Support vread interaction\n**Description**: "Server SHOULD support vread"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHOULD\n**Source**: PractitionerRole Profile Interaction Summary',
#   'id': 'md43'},
#  {'text': ' "This implementation guide... profiles resources from US Core STU 4, where available (Practitioner, Organization and Location), and otherwise from R4 (OrganizationAffiliation, PractitionerRole, HealthCareService, Endpoint)"\n',
#   'raw': '\n\n**Summary**: Base resource profiles on US Core where available\n**Description**: "This implementation guide... profiles resources from US Core STU 4, where available (Practitioner, Organization and Location), and otherwise from R4 (OrganizationAffiliation, PractitionerRole, HealthCareService, Endpoint)"\n**Verification**: Inspection\n**Notes**: Actor: Implementation Guide/Profile Authors, Conformance: SHALL, Conditional: False  \n**Source**: Relation to US Core and other IGs Section\n\n',
#   'id': 'md44'},
#  {'text': ' "This is a query only API (GET) and does not support PUT or POST"\n',
#   'raw': '\n\n**Summary**: Query-only API capability\n**Description**: "This is a query only API (GET) and does not support PUT or POST"\n**Verification**: Test\n**Notes**: Actor: Health Plan API Actor, Conformance: SHALL, Conditional: False\n**Source**: Introduction Section\n\n',
#   'id': 'md45'},
#  {'text': ' "This implementation guide assumes that the directory endpoint is known to the client. There is an overarching system architecture issue that is critical to resolve -- how does the client discover the FHIR endpoint of interest. For the purposes of this IG, we consider that problem out of scope."\n',
#   'raw': '\n\n**Summary**: Endpoint discovery out of scope\n**Description**: "This implementation guide assumes that the directory endpoint is known to the client. There is an overarching system architecture issue that is critical to resolve -- how does the client discover the FHIR endpoint of interest. For the purposes of this IG, we consider that problem out of scope."\n**Verification**: Inspection\n**Notes**: Actor: Application Actor, Conformance: SHALL, Conditional: False\n**Source**: Disclaimers and Assumptions Section\n```This chunk of the Implementation Guide contains no testable requirements - it is acknowledgement and credits text only. Moving to next chunk.This content chunk contains only dependency declarations and package version information without any explicit conformance statements or testable requirements. There are no INCOSE-style requirements to extract from this section.This content appears to be a dependency list of FHIR packages and implementation guides. While it provides important contextual information about required dependencies, it does not contain any explicit, testable requirements with conformance language (SHALL, SHOULD, MAY, etc.). No INCOSE-style requirements can be extracted from this particular content section.This content does not contain any explicit testable requirements - it appears to be a list of package dependencies and their descriptions without any SHALL, SHOULD, MAY or other conformance language. No INCOSE-style requirements can be extracted from this text.This content chunk contains only informational text about licensing and intellectual property rights. It does not contain any explicit conformance language or testable requirements that could be formatted according to INCOSE standards. There are no requirements to extract from this section.From the provided content chunk, I do not find any specific testable requirements containing explicit conformance language (SHALL, SHOULD, MAY, MUST, etc.). The content appears to be a list of links and references without stating any explicit requirements.This content appears to be a metadata listing of code systems, value sets, and extensions without any actual requirements text containing conformance language (SHALL, SHOULD, MAY, etc.). There are no explicit requirements to extract and format according to the INCOSE style specified.This section appears to be a terminology reference list showing code systems, value sets and structure definitions used in the implementation guide. It does not contain any explicit conformance requirements (SHALL, SHOULD, MAY, etc.) that could be formatted into testable requirements. There are no specific behavioral or functional requirements to extract in INCOSE format from this content.```\n\n',
#   'id': 'md46'},
#  {'text': ' "Systems conforming to this implementation guide are expected to declare conformance to one or more of the following capability statements."\n',
#   'raw': '\n\n**Summary**: Declare conformance to capability statements\n**Description**: "Systems conforming to this implementation guide are expected to declare conformance to one or more of the following capability statements."\n**Verification**: Test\n**Notes**: Actor: All Systems, Conformance: SHALL (implied by "expected"), Conditional: False \n**Source**: Behavior: Capability Statements section\n\n',
#   'id': 'md47'},
#  {'text': ' "The Plan-Net Server actor [...] is responsible for providing responses to the queries submitted by the Plan-Net Requestors. Systems implementing this capability statement should meet the CMS Final Rule requirement for provider directory access."\n',
#   'raw': '\n\n**Summary**: Implement Plan-Net Server capabilities\n**Description**: "The Plan-Net Server actor [...] is responsible for providing responses to the queries submitted by the Plan-Net Requestors. Systems implementing this capability statement should meet the CMS Final Rule requirement for provider directory access."\n**Verification**: Test\n**Notes**: Actor: Plan-Net Server, Conformance: SHALL (implied by "responsible"), Conditional: False\n**Source**: Behavior: Capability Statements section',
#   'id': 'md48'},
#  {'text': ' "Select Endpoints managed by the specified organization"\n',
#   'raw': '\n\n**Summary**: Support Endpoint Organization Search Parameter\n**Description**: "Select Endpoints managed by the specified organization"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL (implied by SearchParameter definition), Conditional: False\n**Source**: SearchParameter/endpoint-organization\n\n',
#   'id': 'md49'},
#  {'text': ' "Select HealthcareServices providing the specified category of services"\n',
#   'raw': '\n\n**Summary**: Support HealthcareService Category Search Parameter\n**Description**: "Select HealthcareServices providing the specified category of services"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL (implied by SearchParameter definition), Conditional: False\n**Source**: SearchParameter/healthcareservice-service-category\n\n',
#   'id': 'md50'},
#  {'text': ' "Select services available in a region described by the specified location"\n',
#   'raw': '\n\n**Summary**: Support HealthcareService Coverage Area Search Parameter\n**Description**: "Select services available in a region described by the specified location"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL (implied by SearchParameter definition), Conditional: False\n**Source**: SearchParameter/healthcareservice-coverage-area\n\n',
#   'id': 'md51'},
#  {'text': ' "Select HealthcareServices based on the delivery method type"\n',
#   'raw': '\n\n**Summary**: Support HealthcareService Delivery Method Search Parameter\n**Description**: "Select HealthcareServices based on the delivery method type"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL (implied by SearchParameter definition), Conditional: False\n**Source**: SearchParameter/healthcareservice-delivery-method\n\n',
#   'id': 'md52'},
#  {'text': ' "Select HealthcareServices with the specified endpoint"\n',
#   'raw': '\n\n**Summary**: Support HealthcareService Endpoint Search Parameter\n**Description**: "Select HealthcareServices with the specified endpoint"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL (implied by SearchParameter definition), Conditional: False\n**Source**: SearchParameter/healthcareservice-endpoint\n\n',
#   'id': 'md53'},
#  {'text': ' "Select HealthcareServices available at the specified location"\n',
#   'raw': '\n\n**Summary**: Support HealthcareService Location Search Parameter\n**Description**: "Select HealthcareServices available at the specified location"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL (implied by SearchParameter definition), Conditional: False\n**Source**: SearchParameter/healthcareservice-location\n\n',
#   'id': 'md54'},
#  {'text': ' "Select HealthcareServices with the specified name"\n',
#   'raw': '\n\n**Summary**: Support HealthcareService Name Search Parameter\n**Description**: "Select HealthcareServices with the specified name"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL (implied by SearchParameter definition), Conditional: False\n**Source**: SearchParameter/healthcareservice-name\n\n',
#   'id': 'md55'},
#  {'text': ' "Select HealthcareServices provided by the specified organization"\n',
#   'raw': '\n\n**Summary**: Support HealthcareService Organization Search Parameter\n**Description**: "Select HealthcareServices provided by the specified organization"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL (implied by SearchParameter definition), Conditional: False\n**Source**: SearchParameter/healthcareservice-organization\n\n',
#   'id': 'md56'},
#  {'text': ' "Select services associated with the specified specialty"\n',
#   'raw': '\n\n**Summary**: Support HealthcareService Specialty Search Parameter\n**Description**: "Select services associated with the specified specialty"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL (implied by SearchParameter definition), Conditional: False\n**Source**: SearchParameter/healthcareservice-specialty\n\n',
#   'id': 'md57'},
#  {'text': ' "Select HealthcareServices of the specified type"\n',
#   'raw': '\n\n**Summary**: Support HealthcareService Type Search Parameter\n**Description**: "Select HealthcareServices of the specified type"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL (implied by SearchParameter definition), Conditional: False\n**Source**: SearchParameter/healthcareservice-service-type\n\n',
#   'id': 'md58'},
#  {'text': ' "Select products that are administered by the specified organization"\n',
#   'raw': '\n\n**Summary**: Support InsurancePlan Administered-by Search Parameter\n**Description**: "Select products that are administered by the specified organization"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL (implied by SearchParameter definition), Conditional: False\n**Source**: SearchParameter/insuranceplan-administered-by\n\n',
#   'id': 'md59'},
#  {'text': ' "Select products that are offered in the specified location"\n',
#   'raw': '\n\n**Summary**: Support InsurancePlan Coverage Area Search Parameter\n**Description**: "Select products that are offered in the specified location"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL (implied by SearchParameter definition), Conditional: False\n**Source**: SearchParameter/insuranceplan-coverage-area\n\n',
#   'id': 'md60'},
#  {'text': ' "Select products with the specified identifier"\n',
#   'raw': '\n\n**Summary**: Support InsurancePlan Identifier Search Parameter\n**Description**: "Select products with the specified identifier"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL (implied by SearchParameter definition), Conditional: False\n**Source**: SearchParameter/insuranceplan-identifier\n\n',
#   'id': 'md61'},
#  {'text': ' "Select products with the specified name"\n',
#   'raw': '\n\n**Summary**: Support InsurancePlan Name Search Parameter\n**Description**: "Select products with the specified name"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL (implied by SearchParameter definition), Conditional: False\n**Source**: SearchParameter/insuranceplan-name\n\n',
#   'id': 'md62'},
#  {'text': ' "Select Organization entries in a given InsurancePlan\'s network"\n',
#   'raw': '\n\n**Summary**: Support InsurancePlan Network Search Parameter\n**Description**: "Select Organization entries in a given InsurancePlan\'s network"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL (implied by SearchParameter definition), Conditional: False\n**Source**: SearchParameter/insuranceplan-network\n\n',
#   'id': 'md63'},
#  {'text': ' "Select products that are owned by the specified organization"\n',
#   'raw': '\n\n**Summary**: Support InsurancePlan Owned-by Search Parameter\n**Description**: "Select products that are owned by the specified organization"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL (implied by SearchParameter definition), Conditional: False\n**Source**: SearchParameter/insuranceplan-owned-by\n\n',
#   'id': 'md64'},
#  {'text': ' "Select plans of the specified type"\n',
#   'raw': '\n\n**Summary**: Support InsurancePlan Plan-type Search Parameter\n**Description**: "Select plans of the specified type"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL (implied by SearchParameter definition), Conditional: False\n**Source**: SearchParameter/insuranceplan-plan-type\n\n',
#   'id': 'md65'},
#  {'text': ' "Select insurance plans of the specified type"\n',
#   'raw': '\n\n**Summary**: Support InsurancePlan Type Search Parameter\n**Description**: "Select insurance plans of the specified type"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL (implied by SearchParameter definition), Conditional: False\n**Source**: SearchParameter/insuranceplan-type\n\n',
#   'id': 'md66'},
#  {'text': ' "Select Locations with the specified address"\n',
#   'raw': '\n\n**Summary**: Support Location Address Search Parameter\n**Description**: "Select Locations with the specified address"\n**Verification**: Test\n**Notes**: Actor: Server, Conformance: SHALL (implied by SearchParameter definition), Conditional: False\n**Source**: SearchParameter/location-addressBased on the provided content, this appears to be a list of search parameter definitions without explicit conformance statements (SHALL, SHOULD, MAY, etc.) or testable requirements. The content defines capabilities for searching different resource types but does not specify requirements about their implementation or usage.\n\nSince there are no explicit, testable requirements that meet the INCOSE format criteria in this chunk, I am not generating any formatted requirements. The content appears to be descriptive rather than normative.\n\nNo INCOSE-style requirements can be extracted from this particular chunk of the Implementation Guide.',
#   'id': 'md67'},
#  {'text': ' "When the contact is a department name, rather than a human (e.g., patient help line), [the system] SHALL include a blank family and given name, and provide the department name in contact.name.text"\n',
#   'raw': '\n\n**Summary**: Department Contact Information Format\n**Description**: "When the contact is a department name, rather than a human (e.g., patient help line), [the system] SHALL include a blank family and given name, and provide the department name in contact.name.text"\n**Verification**: Test\n**Notes**: Actor: Implementing System, Conformance: SHALL, Conditional: False (applies whenever contact is a department)\n**Source**: Plan-Net Organization Profile Description\n\n',
#   'id': 'md68'},
#  {'text': ' "The absence of a Practitioner resource does not imply that the Organization itself is playing the role of a Practitioner, instead it implies that that role has been established by the Organization and MAY apply that to a specific Practitioner."\n',
#   'raw': '\n\n**Summary**: PractitionerRole Optional Practitioner Association\n**Description**: "The absence of a Practitioner resource does not imply that the Organization itself is playing the role of a Practitioner, instead it implies that that role has been established by the Organization and MAY apply that to a specific Practitioner."\n**Verification**: Test\n**Notes**: Actor: Implementing System, Conformance: MAY, Conditional: True (when Practitioner resource is absent)\n**Source**: Plan-Net PractitionerRole Profile Description',
#   'id': 'md69'},
#  {'text': ' "If service delivery is virtual, one or more delivery modalities should be specified."\n',
#   'raw': '\n\n**Summary**: Specify delivery modalities for virtual service\n**Description**: "If service delivery is virtual, one or more delivery modalities should be specified."\n**Verification**: Test\n**Notes**: Actor: System, Conformance: SHOULD, Conditional: True (only if service delivery is virtual)\n**Source**: Delivery Method Extension Definition\n\n',
#   'id': 'md70'},
#  {'text': ' "While the role is constrained to participation in a single network where it describes the single role this practitioner is playing (e.g., internal medicine physician) this does not in any way prohibit the practitioner from seeing patients from any other network"\n',
#   'raw': '\n\n**Summary**: Accept networks for practitioner roles\n**Description**: "While the role is constrained to participation in a single network where it describes the single role this practitioner is playing (e.g., internal medicine physician) this does not in any way prohibit the practitioner from seeing patients from any other network"\n**Verification**: Test\n**Notes**: Actor: System, Conformance: SHALL NOT (prohibit), Conditional: False\n**Source**: New Patients Extension Definition\n\n',
#   'id': 'md71'},
#  {'text': ' "Endpoint Payload Types are constrained to NA (Not Applicable) as part of this IG"\n',
#   'raw': '\n\n**Summary**: Endpoint payload type constraint\n**Description**: "Endpoint Payload Types are constrained to NA (Not Applicable) as part of this IG"\n**Verification**: Test\n**Notes**: Actor: System, Conformance: SHALL, Conditional: False\n**Source**: Endpoint Payload Types VS',
#   'id': 'md72'},
#  {'text': ' "Systems conforming to this implementation guide SHALL use the Accepting Patients Codes code system to identify if the practice is accepting new patients"\n',
#   'raw': '\n\n**Summary**: Code system support for accepting patients status\n**Description**: "Systems conforming to this implementation guide SHALL use the Accepting Patients Codes code system to identify if the practice is accepting new patients"\n**Verification**: Test\n**Notes**: Actor: Conforming Systems, Conformance: SHALL, Conditional: False\n**Source**: Terminology: Code Systems - Accepting Patients Codes\n\n',
#   'id': 'md73'},
#  {'text': ' "Systems conforming to this implementation guide SHALL use the Accessibility CS code system for general categories of accommodations available"\n',
#   'raw': ' \n\n**Summary**: Code system support for accessibility categories\n**Description**: "Systems conforming to this implementation guide SHALL use the Accessibility CS code system for general categories of accommodations available"\n**Verification**: Test\n**Notes**: Actor: Conforming Systems, Conformance: SHALL, Conditional: False\n**Source**: Terminology: Code Systems - Accessibility CS\n\n',
#   'id': 'md74'},
#  {'text': ' "Systems conforming to this implementation guide SHALL use the Delivery Methods code system for categories of healthcare service delivery methods"\n',
#   'raw': '\n\n**Summary**: Code system support for delivery methods\n**Description**: "Systems conforming to this implementation guide SHALL use the Delivery Methods code system for categories of healthcare service delivery methods"\n**Verification**: Test\n**Notes**: Actor: Conforming Systems, Conformance: SHALL, Conditional: False \n**Source**: Terminology: Code Systems - Delivery Methods\n\n',
#   'id': 'md75'},
#  {'text': ' "Systems conforming to this implementation guide SHALL constrain Endpoint Payload Types to NA (Not Applicable) as part of this IG"\n',
#   'raw': '\n\n**Summary**: Code system support for endpoint payload types\n**Description**: "Systems conforming to this implementation guide SHALL constrain Endpoint Payload Types to NA (Not Applicable) as part of this IG"\n**Verification**: Test\n**Notes**: Actor: Conforming Systems, Conformance: SHALL, Conditional: False\n**Source**: Terminology: Code Systems - Endpoint Payload Types\n\n',
#   'id': 'md76'},
#  {'text': ' "Systems conforming to this implementation guide SHALL use the Healthcare Service Category code system for broad categories of healthcare services being performed or delivered"\n',
#   'raw': '\n\n**Summary**: Code system support for healthcare service categories \n**Description**: "Systems conforming to this implementation guide SHALL use the Healthcare Service Category code system for broad categories of healthcare services being performed or delivered"\n**Verification**: Test\n**Notes**: Actor: Conforming Systems, Conformance: SHALL, Conditional: False\n**Source**: Terminology: Code Systems - Healthcare Service Category\n\n',
#   'id': 'md77'},
#  {'text': ' "Systems conforming to this implementation guide SHALL use the Insurance Plan Type code system for categories of cost-sharing used by plans"\n',
#   'raw': '\n\n**Summary**: Code system support for insurance plan types\n**Description**: "Systems conforming to this implementation guide SHALL use the Insurance Plan Type code system for categories of cost-sharing used by plans"\n**Verification**: Test\n**Notes**: Actor: Conforming Systems, Conformance: SHALL, Conditional: False\n**Source**: Terminology: Code Systems - Insurance Plan Type\n\n',
#   'id': 'md78'},
#  {'text': ' "Systems conforming to this implementation guide SHALL use the Insurance Product Type code system for distinct packages of health insurance coverage benefits offered using a particular product network type"\n',
#   'raw': '\n\n**Summary**: Code system support for insurance product types\n**Description**: "Systems conforming to this implementation guide SHALL use the Insurance Product Type code system for distinct packages of health insurance coverage benefits offered using a particular product network type"\n**Verification**: Test\n**Notes**: Actor: Conforming Systems, Conformance: SHALL, Conditional: False\n**Source**: Terminology: Code Systems - Insurance Product Type\n\n',
#   'id': 'md79'},
#  {'text': ' "Systems conforming to this implementation guide SHALL use the Language Proficiency CS code system for documenting spoken language proficiency based on the Interagency Language Roundtable scale"\n',
#   'raw': '\n\n**Summary**: Code system support for language proficiency\n**Description**: "Systems conforming to this implementation guide SHALL use the Language Proficiency CS code system for documenting spoken language proficiency based on the Interagency Language Roundtable scale"\n**Verification**: Test\n**Notes**: Actor: Conforming Systems, Conformance: SHALL, Conditional: False\n**Source**: Terminology: Code Systems - Language Proficiency CS\n\n',
#   'id': 'md80'},
#  {'text': ' "Systems conforming to this implementation guide SHALL use the Organization Affiliation Role code system for codes for organization affiliation roles"\n',
#   'raw': '\n\n**Summary**: Code system support for organization affiliation roles\n**Description**: "Systems conforming to this implementation guide SHALL use the Organization Affiliation Role code system for codes for organization affiliation roles"\n**Verification**: Test\n**Notes**: Actor: Conforming Systems, Conformance: SHALL, Conditional: False\n**Source**: Terminology: Code Systems - Organization Affiliation Role\n\n',
#   'id': 'md81'},
#  {'text': ' "Systems conforming to this implementation guide SHALL use the Organization Type code system for categories of organizations based on criteria in provider directories"\n',
#   'raw': '\n\n**Summary**: Code system support for organization types\n**Description**: "Systems conforming to this implementation guide SHALL use the Organization Type code system for categories of organizations based on criteria in provider directories"\n**Verification**: Test\n**Notes**: Actor: Conforming Systems, Conformance: SHALL, Conditional: False\n**Source**: Terminology: Code Systems - Organization Type\n\n',
#   'id': 'md82'},
#  {'text': ' "Systems conforming to this implementation guide SHALL use the Provider Role Codes code system for capabilities that individuals, groups, or organizations are acknowledged to have in a payer network"\n',
#   'raw': '\n\n**Summary**: Code system support for provider roles\n**Description**: "Systems conforming to this implementation guide SHALL use the Provider Role Codes code system for capabilities that individuals, groups, or organizations are acknowledged to have in a payer network"\n**Verification**: Test\n**Notes**: Actor: Conforming Systems, Conformance: SHALL, Conditional: False\n**Source**: Terminology: Code Systems - Provider Role Codes\n\n',
#   'id': 'md83'},
#  {'text': ' "Systems conforming to this implementation guide SHALL use the Qualification Status code system for states indicating if a qualification is currently valid"\n',
#   'raw': '\n\n**Summary**: Code system support for qualification status\n**Description**: "Systems conforming to this implementation guide SHALL use the Qualification Status code system for states indicating if a qualification is currently valid"\n**Verification**: Test\n**Notes**: Actor: Conforming Systems, Conformance: SHALL, Conditional: False\n**Source**: Terminology: Code Systems - Qualification Status\n\n',
#   'id': 'md84'},
#  {'text': ' "Systems conforming to this implementation guide SHALL use the Virtual Modalities code system for categories of virtual service delivery modalities"\n',
#   'raw': '\n\n**Summary**: Code system support for virtual modalities\n**Description**: "Systems conforming to this implementation guide SHALL use the Virtual Modalities code system for categories of virtual service delivery modalities"\n**Verification**: Test\n**Notes**: Actor: Conforming Systems, Conformance: SHALL, Conditional: False\n**Source**: Terminology: Code Systems - Virtual Modalities\n```This section of the FHIR Implementation Guide appears to be a listing of example instances and does not contain any specific, testable requirements with conformance language (SHALL, SHOULD, MAY, etc.). Therefore, there are no INCOSE-style requirements to extract from this content.',
#   'id': 'md85'},
#  {'text': 'A conformant Plan-Net service SHALL NOT require a directory mobile application to send consumer identifying information in order to query content',
#   'raw': {'Requirement*': 'A conformant Plan-Net service SHALL NOT require a directory mobile application to send consumer identifying information in order to query content',
#    'Conformance*': 'SHALL NOT',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Privacy',
#    'Test Plan': 'Verify queries succeed without including any consumer identifying information'},
#   'id': 'rag1'},
#  {'text': 'A directory mobile application SHALL NOT send consumer identifiable information when querying a Plan-Net service',
#   'raw': {'Requirement*': 'A directory mobile application SHALL NOT send consumer identifiable information when querying a Plan-Net service',
#    'Conformance*': 'SHALL NOT',
#    'Actor*': 'Client',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Privacy',
#    'Test Plan': 'Verify client queries do not include consumer identifying information'},
#   'id': 'rag2'},
#  {'text': 'Clients that cache query results can track additions or modifications to directory content through queries that filter content using the _lastUpdated search parameter',
#   'raw': {'Requirement*': 'Clients that cache query results can track additions or modifications to directory content through queries that filter content using the _lastUpdated search parameter',
#    'Conformance*': 'SHOULD',
#    'Actor*': 'Client',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Cache Management',
#    'Test Plan': 'Verify that client performs _lastUpdated queries to detect changes in cached content',
#    'Simulation Approach': 'TESTER-DIRECTED: Ask tester to demonstrate their cache update mechanism using _lastUpdated parameter'},
#   'id': 'rag3'},
#  {'text': 'Clients should periodically check that data cached from past queries has not been deleted by querying for the same elements by _id',
#   'raw': {'Requirement*': 'Clients should periodically check that data cached from past queries has not been deleted by querying for the same elements by _id',
#    'Conformance*': 'SHOULD',
#    'Actor*': 'Client',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Cache Management',
#    'Test Plan': 'Verify that client performs _id queries to detect deletions of cached content',
#    'Simulation Approach': 'TESTER-DIRECTED: Ask tester to demonstrate their cache validation mechanism using _id parameter'},
#   'id': 'rag4'},
# ...
#  {'text': 'Server SHALL support returning an OrganizationAffiliation resource using GET [base]/OrganizationAffiliation/[id]',
#   'raw': {'Requirement*': 'Server SHALL support returning an OrganizationAffiliation resource using GET [base]/OrganizationAffiliation/[id]',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Read'},
#   'id': 'rag99'},
#  {'text': 'Server SHALL support _include parameter for OrganizationAffiliation:primary-organization',
#   'raw': {'Requirement*': 'Server SHALL support _include parameter for OrganizationAffiliation:primary-organization',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag100'},
#  {'text': 'Server SHALL support _include parameter for OrganizationAffiliation:participating-organization',
#   'raw': {'Requirement*': 'Server SHALL support _include parameter for OrganizationAffiliation:participating-organization',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag101'},
#  {'text': 'Server SHALL support _include parameter for OrganizationAffiliation:location',
#   'raw': {'Requirement*': 'Server SHALL support _include parameter for OrganizationAffiliation:location',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag102'},
#  {'text': 'Server SHALL support _include parameter for OrganizationAffiliation:service',
#   'raw': {'Requirement*': 'Server SHALL support _include parameter for OrganizationAffiliation:service',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag103'},
#  {'text': 'Server SHALL support _include parameter for OrganizationAffiliation:endpoint',
#   'raw': {'Requirement*': 'Server SHALL support _include parameter for OrganizationAffiliation:endpoint',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag104'},
#  {'text': 'Server SHALL support _include parameter for OrganizationAffiliation:network',
#   'raw': {'Requirement*': 'Server SHALL support _include parameter for OrganizationAffiliation:network',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag105'},
#  {'text': 'Server SHALL support primary-organization search parameter for OrganizationAffiliation',
#   'raw': {'Requirement*': 'Server SHALL support primary-organization search parameter for OrganizationAffiliation',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Search'},
#   'id': 'rag106'},
#  {'text': 'Server SHALL support participating-organization search parameter for OrganizationAffiliation',
#   'raw': {'Requirement*': 'Server SHALL support participating-organization search parameter for OrganizationAffiliation',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Search'},
#   'id': 'rag107'},
#  {'text': 'Server SHALL support location search parameter for OrganizationAffiliation',
#   'raw': {'Requirement*': 'Server SHALL support location search parameter for OrganizationAffiliation',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Search'},
#   'id': 'rag108'},
#  {'text': 'Server SHALL support service search parameter for OrganizationAffiliation',
#   'raw': {'Requirement*': 'Server SHALL support service search parameter for OrganizationAffiliation',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Search'},
#   'id': 'rag109'},
#  {'text': 'Server SHALL support network search parameter for OrganizationAffiliation',
#   'raw': {'Requirement*': 'Server SHALL support network search parameter for OrganizationAffiliation',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Search'},
#   'id': 'rag110'},
#  {'text': 'Server SHALL support endpoint search parameter for OrganizationAffiliation',
#   'raw': {'Requirement*': 'Server SHALL support endpoint search parameter for OrganizationAffiliation',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Search'},
#   'id': 'rag111'},
#  {'text': 'Server SHALL support role search parameter for OrganizationAffiliation',
#   'raw': {'Requirement*': 'Server SHALL support role search parameter for OrganizationAffiliation',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Search'},
#   'id': 'rag112'},
#  {'text': 'Server SHALL support specialty search parameter for OrganizationAffiliation',
#   'raw': {'Requirement*': 'Server SHALL support specialty search parameter for OrganizationAffiliation',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Search'},
#   'id': 'rag113'},
#  {'text': 'Server SHALL support _id search parameter for OrganizationAffiliation',
#   'raw': {'Requirement*': 'Server SHALL support _id search parameter for OrganizationAffiliation',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Search'},
#   'id': 'rag114'},
#  {'text': 'Server SHALL support _lastUpdated search parameter for OrganizationAffiliation',
#   'raw': {'Requirement*': 'Server SHALL support _lastUpdated search parameter for OrganizationAffiliation',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Grouping': 'Search'},
#   'id': 'rag115'},
#  {'text': 'Profile Support: SHALL support Plan-Net Practitioner profile',
#   'raw': {'Requirement*': 'Profile Support: SHALL support Plan-Net Practitioner profile',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Profile Support',
#    'Test Plan': 'Verify profile is listed in CapabilityStatement',
#    'Simulation Approach': 'SIMULATED: Profile will be listed in CapabilityStatement'},
#   'id': 'rag116'},
#  {'text': 'SHALL support search-type interaction',
#   'raw': {'Requirement*': 'SHALL support search-type interaction',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Interactions',
#    'Test Plan': 'Verify search interaction is listed in CapabilityStatement and test search functionality',
#    'Simulation Approach': 'SIMULATED: Search interaction will be supported'},
#   'id': 'rag117'},
#  {'text': 'SHALL support read interaction',
#   'raw': {'Requirement*': 'SHALL support read interaction',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Interactions',
#    'Test Plan': 'Verify read interaction is listed in CapabilityStatement and test read functionality',
#    'Simulation Approach': 'SIMULATED: Read interaction will be supported'},
#   'id': 'rag118'},
#  {'text': 'SHOULD support vread interaction',
#   'raw': {'Requirement*': 'SHOULD support vread interaction',
#    'Conformance*': 'SHOULD',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Interactions',
#    'Test Plan': 'Verify vread interaction is listed in CapabilityStatement if supported',
#    'Simulation Approach': 'SIMULATED: VRead interaction will be supported'},
#   'id': 'rag119'},
#  {'text': 'SHALL support _revinclude of PractitionerRole:practitioner',
#   'raw': {'Requirement*': 'SHALL support _revinclude of PractitionerRole:practitioner',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameters',
#    'Test Plan': 'Test search with _revinclude parameter',
#    'Simulation Approach': 'SIMULATED: _revinclude parameter will be supported'},
#   'id': 'rag120'},
#  {'text': 'SHALL support name search parameter',
#   'raw': {'Requirement*': 'SHALL support name search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameters',
#    'Test Plan': 'Test search using name parameter',
#    'Simulation Approach': 'SIMULATED: Name search parameter will be supported'},
#   'id': 'rag121'},
#  {'text': 'SHALL support _id search parameter',
#   'raw': {'Requirement*': 'SHALL support _id search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameters',
#    'Test Plan': 'Test search using _id parameter',
#    'Simulation Approach': 'SIMULATED: _id search parameter will be supported'},
#   'id': 'rag122'},
#  {'text': 'SHALL support _lastUpdated search parameter',
#   'raw': {'Requirement*': 'SHALL support _lastUpdated search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameters',
#    'Test Plan': 'Test search using _lastUpdated parameter',
#    'Simulation Approach': 'SIMULATED: _lastUpdated search parameter will be supported'},
#   'id': 'rag123'},
#  {'text': 'SHALL support family search parameter',
#   'raw': {'Requirement*': 'SHALL support family search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameters',
#    'Test Plan': 'Test search using family parameter',
#    'Simulation Approach': 'SIMULATED: Family search parameter will be supported'},
#   'id': 'rag124'},
#  {'text': 'SHALL support given search parameter',
#   'raw': {'Requirement*': 'SHALL support given search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameters',
#    'Test Plan': 'Test search using given parameter',
#    'Simulation Approach': 'SIMULATED: Given search parameter will be supported'},
#   'id': 'rag125'},
#  {'text': 'PractitionerRole Conformance Expectation: SHALL',
#   'raw': {'Requirement*': 'PractitionerRole Conformance Expectation: SHALL',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'CapabilityStatement'},
#   'id': 'rag126'},
#  {'text': 'Server SHALL support search-type interaction for PractitionerRole',
#   'raw': {'Requirement*': 'Server SHALL support search-type interaction for PractitionerRole',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search'},
#   'id': 'rag127'},
#  {'text': 'Server SHALL support read interaction for PractitionerRole',
#   'raw': {'Requirement*': 'Server SHALL support read interaction for PractitionerRole',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Read'},
#   'id': 'rag128'},
#  {'text': 'Server SHOULD support vread interaction for PractitionerRole',
#   'raw': {'Requirement*': 'Server SHOULD support vread interaction for PractitionerRole',
#    'Conformance*': 'SHOULD',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Version Read'},
#   'id': 'rag129'},
#  {'text': 'Server SHALL support _include=PractitionerRole:practitioner',
#   'raw': {'Requirement*': 'Server SHALL support _include=PractitionerRole:practitioner',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag130'},
#  {'text': 'Server SHALL support _include=PractitionerRole:organization',
#   'raw': {'Requirement*': 'Server SHALL support _include=PractitionerRole:organization',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag131'},
#  {'text': 'Server SHALL support _include=PractitionerRole:location',
#   'raw': {'Requirement*': 'Server SHALL support _include=PractitionerRole:location',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag132'},
#  {'text': 'Server SHALL support _include=PractitionerRole:service',
#   'raw': {'Requirement*': 'Server SHALL support _include=PractitionerRole:service',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag133'},
#  {'text': 'Server SHALL support _include=PractitionerRole:network',
#   'raw': {'Requirement*': 'Server SHALL support _include=PractitionerRole:network',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag134'},
#  {'text': 'Server SHALL support _include=PractitionerRole:endpoint',
#   'raw': {'Requirement*': 'Server SHALL support _include=PractitionerRole:endpoint',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Include'},
#   'id': 'rag135'},
#  {'text': 'Server SHALL support practitioner search parameter',
#   'raw': {'Requirement*': 'Server SHALL support practitioner search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameter'},
#   'id': 'rag136'},
#  {'text': 'Server SHALL support organization search parameter',
#   'raw': {'Requirement*': 'Server SHALL support organization search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameter'},
#   'id': 'rag137'},
#  {'text': 'Server SHALL support location search parameter',
#   'raw': {'Requirement*': 'Server SHALL support location search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameter'},
#   'id': 'rag138'},
#  {'text': 'Server SHALL support service search parameter',
#   'raw': {'Requirement*': 'Server SHALL support service search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameter'},
#   'id': 'rag139'},
#  {'text': 'Server SHALL support network search parameter',
#   'raw': {'Requirement*': 'Server SHALL support network search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameter'},
#   'id': 'rag140'},
#  {'text': 'Server SHALL support endpoint search parameter',
#   'raw': {'Requirement*': 'Server SHALL support endpoint search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameter'},
#   'id': 'rag141'},
#  {'text': 'Server SHALL support role search parameter',
#   'raw': {'Requirement*': 'Server SHALL support role search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameter'},
#   'id': 'rag142'},
#  {'text': 'Server SHALL support specialty search parameter',
#   'raw': {'Requirement*': 'Server SHALL support specialty search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameter'},
#   'id': 'rag143'},
#  {'text': 'Server SHALL support _id search parameter',
#   'raw': {'Requirement*': 'Server SHALL support _id search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameter'},
#   'id': 'rag144'},
#  {'text': 'Server SHALL support _lastUpdated search parameter',
#   'raw': {'Requirement*': 'Server SHALL support _lastUpdated search parameter',
#    'Conformance*': 'SHALL',
#    'Actor*': 'Server',
#    'Verifiable?': 'Yes',
#    'Planning To Test?': 'Yes',
#    'Grouping': 'Search Parameter'},
#   'id': 'rag145'}]

# %%
set(list(dupdf['Requirement1'].unique()) + list(dupdf['Requirement2'].unique()))
# Out:
# {'md0',
#  'md14',
#  'md18',
#  'md2',
#  'md21',
#  'md26',
#  'md30',
#  'md34',
#  'md38',
#  'rag0',
#  'rag2'}

# %%
set(subdf['Requirement1'].to_list() + subdf['Requirement2'].to_list()).union(set(['11']))
# Out:
# {'11', 'md0', 'rag0'}

# %%
dupdf
# Out:
#       Requirement1 Requirement2  Similarity Score
# 85             md0         rag0          0.982360
# 549            md2         rag2          0.984251
# 3251          md14         md18          1.000000
# 3254          md14         md21          1.000000
# 3259          md14         md26          1.000000
# 3263          md14         md30          1.000000
# 3267          md14         md34          1.000000
# 3271          md14         md38          0.983983
# 4172          md18         md14          1.000000
# 4178          md18         md21          1.000000
# 4183          md18         md26          1.000000
# 4187          md18         md30          1.000000
# 4191          md18         md34          1.000000
# 4195          md18         md38          0.983983
# 4865          md21         md14          1.000000
# 4869          md21         md18          1.000000
# 4876          md21         md26          1.000000
# 4880          md21         md30          1.000000
# 4884          md21         md34          1.000000
# 4888          md21         md38          0.983983
# 6020          md26         md14          1.000000
# 6024          md26         md18          1.000000
# 6027          md26         md21          1.000000
# 6035          md26         md30          1.000000
# 6039          md26         md34          1.000000
# 6043          md26         md38          0.983983
# 6944          md30         md14          1.000000
# 6948          md30         md18          1.000000
# 6951          md30         md21          1.000000
# 6956          md30         md26          1.000000
# 6963          md30         md34          1.000000
# 6967          md30         md38          0.983983
# 7868          md34         md14          1.000000
# 7872          md34         md18          1.000000
# 7875          md34         md21          1.000000
# 7880          md34         md26          1.000000
# 7884          md34         md30          1.000000
# 7891          md34         md38          0.983983
# 8792          md38         md14          0.983983
# 8796          md38         md18          0.983983
# 8799          md38         md21          0.983983
# 8804          md38         md26          0.983983
# 8808          md38         md30          0.983983
# 8812          md38         md34          0.983983
# 19866         rag0          md0          0.982360
# 20330         rag2          md2          0.984251
