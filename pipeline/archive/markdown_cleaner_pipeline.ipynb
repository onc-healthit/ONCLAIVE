# %% [markdown]
# # Cleaning Markdown Files for API Pipeline
# This script removes unnecessary headers and footers, as well as white space and lines.
#
# Before running, set input directory to folder where markdown files are stored post-HTML conversion.
#
# Cleaned files will be saved to 'markdown_cleaned' output directory.

# %%
# # Set input and output directories
# input_dir = "/Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_output"
# output_dir = "/Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned"

# %%
import os
import re
import argparse
from pathlib import Path

# %%
def clean_markdown_file(file_path):
    """
    Clean a markdown file by removing the header and footer content.
    
    Args:
        file_path (str): Path to the markdown file
        
    Returns:
        str: Cleaned markdown content
    """
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
            
        # Remove the XML declaration and encoding line
        content = re.sub(r'xml version\=\"1\.0\" encoding\=\"UTF\-8\"\?', '', content)
        
        # Find where the main content starts (after the Table of Contents marker)
        toc_pattern = r'\* \[\*\*Table of Contents\*\*\]\(toc\.html\)\s*\n\* \*\*([^*]+)\*\*'
        match = re.search(toc_pattern, content)
        
        if match:
            # Get the title of the document (to preserve it)
            title = match.group(1).strip()
            
            # Find the position after the TOC line
            toc_end_pos = match.end()
            content_after_toc = content[toc_end_pos:]
            
            # Find the beginning of the main content (after empty lines following TOC)
            main_content_start = re.search(r'\n\s*\n', content_after_toc)
            if main_content_start:
                main_content_start_pos = main_content_start.end() + toc_end_pos
                main_content = content[main_content_start_pos:]
            else:
                main_content = content_after_toc
                
            # Remove footer content with a more specific pattern
            # Explicitly search for the footer markers
            footer_start = re.search(r'(\n\s*IG ©|\n IG ©|\n\s*Links:)', main_content)
            if footer_start:
                main_content = main_content[:footer_start.start()]
            
            # Add the title as a proper markdown heading
            cleaned_content = f"# {title}\n\n{main_content.strip()}"
            
            # Clean up excessive whitespace and escape characters
            cleaned_content = re.sub(r'\\\-', '-', cleaned_content)  # Fix escaped hyphens
            cleaned_content = re.sub(r'\\\+', '+', cleaned_content)  # Fix escaped plus signs
            cleaned_content = re.sub(r'\\\|', '|', cleaned_content)  # Fix escaped pipes
            cleaned_content = re.sub(r'\\\.', '.', cleaned_content)  # Fix escaped periods
            cleaned_content = re.sub(r'\s+\n', '\n', cleaned_content)  # Remove trailing whitespace
            cleaned_content = re.sub(r'\n{3,}', '\n\n', cleaned_content)  # Normalize multiple newlines
            
            return cleaned_content
        else:
            # If TOC pattern not found, try to find content after header in a different way
            # Find the end of the last navigation list item
            nav_end = re.search(r'\* \[[^\]]+\]\([^)]+\)\s*\n\s*\n', content)
            if nav_end:
                main_content = content[nav_end.end():]
                
                # Remove footer content
                footer_start = re.search(r'(\n\s*IG ©|\n IG ©|\n\s*Links:)', main_content)
                if footer_start:
                    main_content = main_content[:footer_start.start()]
                
                # Try to find a title
                title_match = re.search(r'## ([^\n]+)', main_content)
                title = title_match.group(1) if title_match else "Document"
                
                return f"# {title}\n\n{main_content.strip()}"
            else:
                # If all else fails, just return the content with footer removed
                footer_start = re.search(r'(\n\s*IG ©|\n IG ©|\n\s*Links:)', content)
                if footer_start:
                    content = content[:footer_start.start()]
                return content.strip()
    
    except Exception as e:
        print(f"Error processing {file_path}: {str(e)}")
        return None

# %%
def process_directory(input_dir, output_dir):
    """
    Process all markdown files in a directory and save cleaned versions.
    
    Args:
        input_dir (str): Directory containing markdown files
        output_dir (str): Directory to save cleaned files
    """
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Get all markdown files in the input directory
    input_path = Path(input_dir)
    md_files = list(input_path.glob('*.md'))
    
    print(f"Found {len(md_files)} markdown files in {input_dir}")
    
    successful = 0
    failed = 0
    
    for file_path in md_files:
        output_path = Path(output_dir) / file_path.name
        cleaned_content = clean_markdown_file(file_path)
        
        if cleaned_content:
            with open(output_path, 'w', encoding='utf-8') as out_file:
                out_file.write(cleaned_content)
            successful += 1
            print(f"Cleaned and saved: {output_path}")
        else:
            failed += 1
    
    print(f"\nProcessing complete: {successful} files successfully cleaned, {failed} failed")

# %%
# Process the files
# process_directory(input_dir, output_dir)
# Out:
# Found 380 markdown files in /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_output
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/PractitionerRole-JoeSmithRole1.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Location-HospLoc1.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-location-endpoint.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/HealthcareService-HartfordOrthopedicServices.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitioner-name.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/implementation.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-EndpointPayloadTypeCS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Organization-definitions.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-practitioner-qualification.profile.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-communication-proficiency-mappings.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/examples.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-InsurancePlan-examples.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/PractitionerRole-JoeSmithRole2.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organizationaffiliation-primary-organization.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organizationaffiliation-specialty.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/HealthcareService-HamiltonClinicServices.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-healthcareservice-location.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitionerrole-period.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-insuranceplan-name.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-QualificationStatusCS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-healthcareservice-endpoint.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-healthcareservice-endpoint.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-location-address-state.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-DeliveryMethodCS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/HealthcareService-PharmChainRetailService.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-healthcareservice-service-type.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/HealthcareService-VirtualCounselService.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-NonIndividualSpecialtyAndDegreeLicenseCertificateVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-insuranceplan-identifier.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-healthcareservice-organization.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-HealthcareServiceTypeVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/OrganizationAffiliation-HamiltonClinicAffil.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-practitioner-qualification-definitions.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-PractitionerRole.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-AcceptingPatientsCS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CapabilityStatement-plan-net.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitionerrole-location.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-location-organization.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitionerrole-endpoint.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organizationaffiliation-location.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organization-coverage-area.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-via-intermediary-definitions.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-HealthcareService-definitions.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-endpoint-usecase-mappings.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-EndpointConnectionTypeVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-newpatients-definitions.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-NonIndividualSpecialtyAndDegreeLicenseCertificateVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Organization-PharmChain.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organizationaffiliation-endpoint.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitionerrole-role.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitionerrole-service.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organizationaffiliation-period.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-IndividualSpecialtyAndDegreeLicenseCertificateVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-IndividualAndGroupSpecialtiesVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Organization-AcmeofCTStdNet.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-org-description.profile.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Location-HansSoloClinic.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-insuranceplan-coverage-area.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-location-organization.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-location-address-state.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Practitioner-Counselor.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Network.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-OrganizationAffiliation-mappings.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Location-HansSoloClinic.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/HealthcareService-BurrClinicServices.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitioner-family-name.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/OrganizationAffiliation-HartfordOrthopedicAffil.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organization-type.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Practitioner-Counselor.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Practitioner-mappings.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Location-HospLoc1.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-endpoint-organization.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Location.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organization-name.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-healthcareservice-location.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Organization-ConnHIE.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Endpoint.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Endpoint-examples.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/HealthcareService-HansSoloService.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organizationaffiliation-network.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-DeliveryMethodVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/OrganizationAffiliation-BurrClinicAffil.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-location-address.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Practitioner-HansSolo.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organizationaffiliation-endpoint.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/PractitionerRole-JoeSmithRole3.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Location-examples.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organizationaffiliation-location.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-QualificationStatusCS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-PractitionerRole-mappings.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitionerrole-specialty.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-NetworkTypeVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/HealthcareService-HospERService.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-healthcareservice-service-category.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-insuranceplan-name.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Location-PharmLoc3.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/PractitionerRole-JoeSmithRole3.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-endpoint-usecase.profile.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Organization-AcmeofCTPremNet.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-network-reference-mappings.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-healthcareservice-coverage-area.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Endpoint-definitions.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-location-address-city.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/profiles.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-VirtualModalitiesCS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-location-type.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-LanguageProficiencyCS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/OrganizationAffiliation-PharmChainAffil3.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/HealthcareService-CancerClinicService.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/HealthcareService-HamiltonClinicServices.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-healthcareservice-service-type.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-via-intermediary-mappings.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-AccessibilityVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-AcceptingPatientsVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-insuranceplan-coverage-area.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-InsurancePlanTypeVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/OrganizationAffiliation-BurrClinicAffil.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Organization-BigBox.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-InsurancePlan-definitions.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/PractitionerRole-AnonRole.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-communication-proficiency.profile.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Practitioner.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-delivery-method-mappings.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/HealthcareService-HartfordOrthopedicServices.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Location-HospLoc2.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitioner-given-name.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-IndividualAndGroupSpecialtiesVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-location-reference-definitions.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organizationaffiliation-network.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-OrganizationAffiliationRoleCS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-qualification.profile.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitionerrole-endpoint.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-NonIndividualSpecialtiesVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-accessibility-mappings.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-insuranceplan-owned-by.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/PractitionerRole-HansSoloRole1.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitionerrole-period.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-EndpointPayloadTypeCS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-InsurancePlan-mappings.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Practitioner-definitions.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/PractitionerRole-JoeSmithRole2.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Network.profile.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ChangeHistory.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Organization-BigBox.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/HealthcareService-BurrClinicServices.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Endpoint-mappings.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-location-address.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-healthcareservice-organization.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Practitioner-examples.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitionerrole-location.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-AcceptingPatientsVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-OrgTypeVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-LanguageProficiencyCS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organization-coverage-area.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/artifacts.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-PractitionerRole-examples.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-HealthcareServiceCategoryCS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-org-description.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitionerrole-practitioner.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Location-mappings.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organization-endpoint.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-OrganizationAffiliation.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/HealthcareService-VirtualCounselService.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Location-PharmLoc2.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitionerrole-network.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organization-endpoint.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-ProviderRoleCS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-EndpointConnectionTypeVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organization-address.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-OrganizationAffiliation-definitions.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/OrganizationAffiliation-PharmChainAffil2.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-location-type.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-contactpoint-availabletime.profile.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-PractitionerRoleVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Endpoint-AcmeOfCTPortalEndpoint.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-newpatients-mappings.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-PractitionerRole.profile.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-contactpoint-availabletime.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-accessibility.profile.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-IndividualSpecialtyAndDegreeLicenseCertificateVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-EndpointConnectionTypeCS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-insuranceplan-administered-by.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-OrganizationAffiliation-examples.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-HealthcareServiceCategoryVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Location-StateOfCTLocation.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-healthcareservice-service-category.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-OrganizationAffiliationRoleVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-SpecialtiesVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Location-definitions.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-InsurancePlanTypeVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-NonIndividualSpecialtiesVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-OrganizationAffiliationRoleCS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organizationaffiliation-role.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-insuranceplan-plan-type.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Location-PharmLoc1.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-InsurancePlanTypeCS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitionerrole-network.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-HealthcareServiceTypeVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-AcceptingPatientsCS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organizationaffiliation-role.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Location-CancerClinicLoc.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-DeliveryMethodCS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Organization-mappings.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-HealthcareService-examples.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/HealthcareService-PharmChainRetailService.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/HealthcareService-PharmChainCompService.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-VirtualModalitiesVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Organization-BurrClinic.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-communication-proficiency-definitions.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-location-address-city.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Organization-CancerClinic.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/HealthcareService-HansSoloService.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Practitioner-HansSolo.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Network-examples.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organization-name.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-org-description-definitions.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitioner-name.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/PractitionerRole-CounselorRole1.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Location-PharmLoc1.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/HealthcareService-HospERService.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-AccessibilityVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/searchform.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/OrganizationAffiliation-HamiltonClinicAffil.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/PractitionerRole-HansSoloRole1.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-location-reference-mappings.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-QualificationStatusVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-PractitionerRoleVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-newpatients.profile.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-newpatients.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/OrganizationAffiliation-PharmChainAffil3.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organization-type.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/OrganizationAffiliation-PharmChainAffil1.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Location-PharmLoc4.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Practitioner.profile.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organizationaffiliation-service.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-InsuranceProductTypeCS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Practitioner-JoeSmith.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Organization-Acme.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Organization-Acme.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-EndpointPayloadTypeVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/index.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitioner-family-name.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-QualificationStatusVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organizationaffiliation-participating-organization.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-practitioner-qualification-mappings.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-InsuranceProductTypeCS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/toc.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Organization-HamiltonClinic.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-OrganizationAffiliationRoleVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-insuranceplan-owned-by.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-delivery-method-definitions.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-HealthcareServiceCategoryCS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-endpoint-organization.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-InsuranceProductTypeVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-EndpointUsecaseVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organizationaffiliation-specialty.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-qualification-definitions.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Practitioner-JoeSmith.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Organization-BurrClinic.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-accessibility.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-DeliveryMethodVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-endpoint-usecase-definitions.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/InsurancePlan-AcmeQHPBronze.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-insuranceplan-type.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-OrgTypeCS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organization-partof.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Organization-CancerClinic.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-network-reference-definitions.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-SpecialtyAndDegreeLicenseCertificateVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-InsuranceProductTypeVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-OrganizationAffiliation.profile.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-SpecialtiesVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-HealthcareServiceCategoryVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Location-PharmLoc4.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-communication-proficiency.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organizationaffiliation-period.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Network-definitions.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-MinEndpointConnectionTypeVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/OrganizationAffiliation-PharmChainAffil2.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organization-partof.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/InsurancePlan-AcmeQHPBronze.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-location-reference.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-location-partof.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-VirtualModalitiesVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-practitioner-qualification.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-OrgTypeVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-endpoint-usecase.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/InsurancePlan-AcmeQHPGold.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/HealthcareService-PharmChainMailService.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Location-PharmLoc3.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-location-endpoint.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-VirtualModalitiesCS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-insuranceplan-plan-type.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Organization-AcmeofCTStdNet.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/OrganizationAffiliation-ConnHIEAffil.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CapabilityStatement-plan-net.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-qualification.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/OrganizationAffiliation-HartfordOrthopedicAffil.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-location-address-postalcode.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Organization.profile.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-insuranceplan-identifier.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/HealthcareService-CancerClinicService.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-healthcareservice-specialty.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-via-intermediary.profile.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Endpoint-AcmeOfCTPortalEndpoint.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-AccessibilityCS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-healthcareservice-name.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-PractitionerRole-definitions.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-contactpoint-availabletime-definitions.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-delivery-method.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitioner-given-name.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-location-partof.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-AccessibilityCS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/InsurancePlan-AcmeQHPGold.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/downloads.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organizationaffiliation-primary-organization.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-contactpoint-availabletime-mappings.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitionerrole-practitioner.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-location-address-postalcode.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-NetworkTypeVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/OrganizationAffiliation-PharmChainAffil1.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Network-mappings.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/OrganizationAffiliation-ConnHIEAffil.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-InsurancePlan.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-location-reference.profile.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/HealthcareService-PharmChainCompService.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-healthcareservice-coverage-area.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitionerrole-service.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Organization-HartfordOrthopedics.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-healthcareservice-specialty.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-insuranceplan-administered-by.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/PractitionerRole-AnonRole.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Organization-examples.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitionerrole-organization.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-HealthcareService-mappings.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-healthcareservice-name.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Location-HospLoc2.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Location-StateOfCTLocation.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Organization-Hospital.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Location-PharmLoc2.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-LanguageProficiencyVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-org-description-mappings.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitionerrole-role.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organizationaffiliation-participating-organization.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-insuranceplan-type.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Organization-Hospital.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-qualification-mappings.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-accessibility-definitions.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-network-reference.profile.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organization-address.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Location.profile.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-network-reference.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/PractitionerRole-JoeSmithRole1.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-MinEndpointConnectionTypeVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-HealthcareService.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Organization-HartfordOrthopedics.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-LanguageProficiencyVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Organization-AcmeofCTPremNet.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-ProviderRoleCS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Endpoint.profile.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Location-CancerClinicLoc.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-delivery-method.profile.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/HealthcareService-PharmChainMailService.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitionerrole-organization.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Organization-ConnHIE.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-EndpointUsecaseVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-organizationaffiliation-service.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/PractitionerRole-CounselorRole1.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-InsurancePlan.profile.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-HealthcareService.profile.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-OrgTypeCS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-via-intermediary.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/SearchParameter-practitionerrole-specialty.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-InsurancePlanTypeCS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-EndpointPayloadTypeVS.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/StructureDefinition-plannet-Organization.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/ValueSet-SpecialtyAndDegreeLicenseCertificateVS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/CodeSystem-EndpointConnectionTypeCS.change.history.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Organization-HamiltonClinic.md
# Cleaned and saved: /Users/ceadams/Documents/onclaive/onclaive/full-ig/markdown_cleaned/Organization-PharmChain.md
#
# Processing complete: 380 files successfully cleaned, 0 failed
